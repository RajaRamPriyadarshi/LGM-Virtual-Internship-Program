# %% [markdown]
# # **IMPORTING LIBRARY**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import  matplotlib.pyplot as plt

# %% [markdown]
# # **IMPORTING DATASET**

# %%
df=pd.read_csv("/content/drive/MyDrive/LGM RAW DATA/iris.data.csv")
df
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %% [markdown]
# # **GETTTING INFORMATION**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sepal length in cm  150 non-null    float64
#  1   sepal width in cm   150 non-null    float64
#  2   petal length in cm  150 non-null    float64
#  3   petal width in cm   150 non-null    float64
#  4   class               150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # **GETTING STATIC VALUES**

# %%
df.describe()
# Out:
#        sepal length in cm  sepal width in cm  petal length in cm  \
# count          150.000000         150.000000          150.000000
# mean             5.843333           3.057333            3.758000
# std              0.828066           0.435866            1.765298
# min              4.300000           2.000000            1.000000
# 25%              5.100000           2.800000            1.600000
# 50%              5.800000           3.000000            4.350000
# 75%              6.400000           3.300000            5.100000
# max              7.900000           4.400000            6.900000
#
#        petal width in cm
# count         150.000000
# mean            1.199333
# std             0.762238
# min             0.100000
# 25%             0.300000
# 50%             1.300000
# 75%             1.800000
# max             2.500000

# %% [markdown]
# # **CHECKING NULL VALUES**

# %%
df.isnull().sum()
# Out:
# sepal length in cm    0
# sepal width in cm     0
# petal length in cm    0
# petal width in cm     0
# class                 0
# dtype: int64

# %% [markdown]
# # **CHECKING SHAPE**

# %%
df.shape
# Out:
# (150, 5)

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# ...

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# # **VISUALISING DATA**

# %%
sns.pairplot(df,hue="class",height=3)

# %% [markdown]
# # **ASSIGNING NEW COLUMN**

# %%
df["species"]=df["class"]

# %% [markdown]
# # **DROPING EXIXTING COLUMN**

# %%
df.drop(["class"],axis=1,inplace=True)

# %%
df.head(5)
# Out:
#    sepal length in cm  sepal width in cm  petal length in cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    petal width in cm      species
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# 3                0.2  Iris-setosa
# 4                0.2  Iris-setosa

# %% [markdown]
# # **IMPORTING LIBRARY**

# %%
from sklearn import preprocessing

# %%
le=preprocessing. LabelEncoder()
le.fit(df.species)
df["encoded"]=le.transform(df.species)
df.head(5)
# Out:
#    sepal length in cm  sepal width in cm  petal length in cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    petal width in cm      species  encoded
# 0                0.2  Iris-setosa        0
# 1                0.2  Iris-setosa        0
# 2                0.2  Iris-setosa        0
# 3                0.2  Iris-setosa        0
# 4                0.2  Iris-setosa        0

# %% [markdown]
# # **DEFINING X AND Y VARIABLE**

# %%
x=df.iloc[:,:4]

# %%
y=df.iloc[:,5]

# %% [markdown]
# # **IMPORTING LIBRARY**

# %%
from sklearn .model_selection import train_test_split
from sklearn.svm import SVC
from sklearn import metrics

# %% [markdown]
# # **INITIALIZING TRAIN TEST SPLIT**

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.30)

# %%
model=SVC(gamma='scale')
model.fit(x_train, y_train)
# Out:
# SVC()

# %% [markdown]
# # **PREDICTING MODEL**

# %%
predict=model.predict(x_test)

# %% [markdown]
# # **EVALUATING MODEL**

# %%
print("Accuracy",round(metrics.accuracy_score(y_test, predict),2)*100)
# Out:
# Accuracy 98.0
